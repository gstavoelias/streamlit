# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 1 - LEITURA DO DF E CONFIGS

import pandas as pd

df = pd.read_excel("erros.xlsx", dtype={"NÚMERO DE SERIE": str})
pd.set_option("display.max_rows", None)

# %%
# 2 - TRATAMENTO DO RESPONSÁVEL E OPERADOR_ID
operador_id_map = {
    "João Pedro": 1,
    "Thiago": 2,
    "Lucas Villani": 3,
    "Mario": 4,
    "Fabiana": 5,
    "Gustavo": 6,
    "Kathleyn": 7,
    "Vinicius R": 8,
    "Silas": 9,
    "Thiago Dias": 10,
    "Indefinido": 11
}

df["RESPONSÁVEL"] = df["RESPONSÁVEL"].str.strip().fillna("Indefinido")
df["OPERADOR_ID"] = df["RESPONSÁVEL"].map(operador_id_map)

# %%
print(len(df["PROBLEMA"]))
print(len(df["PROBLEMA"].unique()))
display(df["PROBLEMA"].value_counts())
# Out:
# 264
# 176
# PROBLEMA
# TCU não liga na bateria                                                                 27
# Falha na comunicação                                                                    11
# 230mA de corrente                                                                       10
# Led invertido                                                                            8
# TCU não comunica serialmente                                                             5
# TCU não ligou na bateria                                                                 4
# TCU não comunica                                                                         4
# 160mA de corrente                                                                        3
# Versão da placa não identificada / Regravação do firmware não solucionou o problema      3
# Led vermelho com defeito                                                                 3
# ...

# %%
# 3 - TRATAMENTO DOS PROBLEMAS

df["PROBLEMA"] = df["PROBLEMA"].str.strip()

substituicoes = {
    # Grupo 10 - LEDs queimados ou invertidos
    "Led invertido": 10,
    "Led vermelho com defeito": 10,
    "TCU não pisca o led vermelho": 10,
    "Leds rosa durante a movimentação": 10,
    "Led invertido e correntede 230mA": 10,
    "Led com cor invertida (lilás) durante a movimentação": 10,
    "Cores do led não conforme (invertido)": 10,
    "Placa energiza ok, mas led não acende": 10,
    "Teste comunicação ok, porém cor do led não conforme": 10,
    "Led não piscou vermelho ao iniciar na bateria": 10,
    "Led vermelho e verde trocados": 10,
    "Led vermelho não piscou": 10,
    "Led ficou verde ao ligar TCU": 10,
    "Cor do led não conforme": 10,
    "TCU led acendendo lilás ao inves de azul": 10,
    "Led vermelho não pisca antes de ligar, liga azul direto": 10,
    "Led apresentou cor rosa durante a movimentação (Padrão é amarelo)": 10,
    "TCU Led invertido e corrente em 220mA": 10,
    "Led com cores não conforme": 10,
    "Led invertido durante a movimentação cor roxa": 10,
    "Lud de LED azul escuro, corrente baixa +- 150mA": 10,
    "Led inoperante ": 10,
    "Led não acendeu ao ligar a TCU": 10,
    "Led da frente não acende": 10,
    "Led inoperante": 10,
    "Led não acendeu ao ligar a TCU na fonte": 10,

    # Grupo 20 - Ponte H defeituosa
    "Falha na ponte H (Leds do motor não acenderam)": 20,
    "1º Falha na Ponte H 2º Placa não comunicou": 20,
    "Falha na ponte H (Led's do motor não acenderam)": 20,
    "Falha na ponte H e falha na comunicação": 20,
    "Ponte H falha ao mover em um dos sentidos. Tensão cai de 24V para 0": 20,
    "Falha na ponte H (Led's do motor não acenderam) (Falha no parâmetros teste potência)": 20,
    "TCU não movimentou durante o teste": 20,
    "TCU não movimenta no burn-in. Regravação do firmware": 20,
    "Sem movimentar": 20,
    "TCU ao movimentar trava no ângulo -27º": 20,
    "Não movimenta": 20,
    "TCU não movimentou burn-in, regravar firmware": 20,
    "Leds da saida do motor não acendem (Firmware já foi regravado)": 20,
    "TCU não movimenta": 20,
    "TCU não movimenta s/ tensão na saida do motor (Componente solto)": 20,
    "TCU não movimenta (Sem tensão na saida do motor)": 20,
    "Leds da saida do motor não acendeu": 20,
    "TCU não movimentou durante o teste no burn in": 20,

    # Grupo 30 - TCU não ligou na bateria (Geral)
    "TCU não liga na bateria": 30,
    "TCU não ligou": 30,
    "110mA de consumo, TCU não liga": 30,
    "TCU não liga na bateria ao colocar fusivel": 30,
    "TCU não liga ao colocar fusível da bateria": 30,
    "TCU não ligou com a fonte": 30,
    "TCU não liga na bateria, led não acende": 30,
    "TCU não liga": 30,
    "TCU não liga a bateria": 30,
    "TCu não liga na bateria": 30,
    "TCI não liga na bateria": 30,
    "Led não acende ao conectar fusível na bateria": 30,
    "LED não acende ao colocar fusível da bateria": 30,
    "TCU não aciona o LED. Case superior com problema na rosca do parafuso": 30,
    "Led não acendeu ao ligar TCU": 30,
    "LED não atendeu ao ligar a TCU": 30,
    "LED não acendeu ao ligar a TCU": 30,


    # Grupo 40 - TCU não comunica
    "TCU não comunica serialmente": 40,
    "TCU não comunica": 40,
    "Não estabelece comunicaçao serial": 40,
    "TCU não comunicou": 40,
    "Não indica teste de comunicação": 40,
    "TCU não comunica serial": 40,
    "TCU não inicia comunicação serial": 40,
    "TCU mão comunica serialmente, luz vermelha no led": 40,
    "Não Iinicia a comunicação": 40,
    "TCU não inicializa teste de comunicação": 40,
    "TCU não estabelece comunicação serial": 40,
    "TCU não espabelece comunicação serial": 40,
    "TCU não iniciou o teste de comunicação": 40,
    "TCU não inicia o teste de comunicação": 40,
    "TCU não iniciou comunicação": 40,
    "Corrente 340mA, Placa não comunicou, cores do led não conforme": 40,
    "Placa não comunicou": 40,
    "TCU não inicia a comunicação": 40,
    "TCU não inicia a comunicação (Problema persiste)": 40,
    "Falha na comunicação com a placa (firmware já regravado)": 40,
    "TCU não comunica, não foi possivel obter informações da placa": 40,
    "Versão da placa não identificada / Regravação do firmware não solucionou o problema": 40,
    "Versão da placa não identificada, (Firmware regravado) (Troca do case superior)": 40,
    "Placa não comunuca durante o teste (Firmware regravado)": 40,
    "Falha na comunicação e led ficou verde": 40,
    "Versão da placa não identificado": 40,


    # Grupo 41 - Comunicação serial intermitente
    "Com intermitente": 41,
    "Comunicação intermitente": 41,
    "TCU com erro de comunicação": 41,
    "1º: Travou no parâmetro de configuração da TCU / 2º: Falha na comunicação serial": 41,
    "Falha na comunicação serial": 41,
    "Falha na comunicação": 41,
    "Ruido durante o teste": 41,
    "Cloud not convert / TCU não movimentou durante teste": 41,

    # Grupo 50 - RAK Defeituosa
    "Falha de comunicação com a RAK": 50,
    "$err, rak not found - falha de comunicação com o rak": 50,
    "Falha nos parâmetros ADC, RAK, EPRON e comunicação": 50,

    # Grupo 60 - TCU não liga na bateria (Corrente baixa)
    "160mA de corrente": 60,
    "TCU com corrente baixa (falha no teste de potência)": 60,
    "150mA de corrente e falha no ADC": 60,
    "150mA de corrente e regravagem do número de serie": 60,
    "TCU variando a corrente": 60,
    "TCU com corrente baixa, não liga": 60,
    "TCU com corrente baixa (110mA)": 60,
    "150mA de corrente": 60,
    "Jiga de corrente no primeiro teste": 60,
    "TCU com corrente baixa (Não liga)": 60,
    "160mA": 60,
    "140mA de consumo": 60,
    "TCU com corrente baixa (110Ma)": 60,
    #Grupo 61 0 TCU não liga na bateria (Correnta alta)
    "TCU com corrente alta (400mA)": 61,
    "Led invertido e 230mA de corrente": 61,
    "230mA de corrente": 61,
    "240mA de corrente, falha no parâmetro Carga da Bateria": 61,
    "230 mA de corrente": 61,
    "TCU com corrente alta 260mA": 61,
    "Step up emcurto, soltou fumaça": 61,
    "TCU em curto (Fusivel rompeu e quebrou dentro do porta fusivel)": 61,
    "TCU com corrente alta em 370mA": 61,
    "TCU em curto corrente alta": 61,
    "340mA de corrente (Conferir led também)": 61,
    "TCU corrente em 230mA": 61,
    "TCU com a corrente alta": 61,
    "Corrente alta (440mA) e led verde": 61,
    "300mA de corrente": 61,
    "240mA de corrente": 61,
    "220mA de corrente": 61,
    "2.25A de corrente": 61,
    "TCU com corrente alta": 61,
    "230mA de corrente, não passou na potência ao conectar na giga": 61,
    "TCU corrente alta demais 270mA": 61,
    "360mA de corrente": 61,
    "TCU com corrente alta (270mA)": 61,
    "TCU com corrente alta (360mA)": 61,
    "2.80A de corrente": 61,

    

    # Grupo 70 - Falha na temporarização
    "TCU não fez temporização ao ligar na fonte": 70,
    "TCU não temporizou durante o teste de carga": 70,
    "TCU não temporizou": 70,

    # Grupo 80 - Problema no ADC
    "Falha no ADC": 80,
    "TCU falha no ADC": 80,
    "Falha na ADC teste comunicação": 80,
    "Erro no ADC, luz azul escuro": 80,
    "Falha no Serial Number e no ADC": 80,

    # Grupo 81 - Problema no RTC
    "TCU erro comunicação no RTC e no EPPROM": 81,
    "Falha no RTC": 81,
    "Falha nos parametros RTC, inclinômetro e EPROM": 81,

    # Grupo 83 - Problema na EEPROM
    "Falha teste de comunicação EPROM e RTC": 83,
    "Erro teste comunicação serial number e epron": 83,

    #Grupo 84 - Problema no Inclinômetro
    "TCU com leitura de angulo invalida. Não movimeta durante o teste": 84,
    "Placa do inclinometro com defeito (LED não acende ao fazer a calibração)": 84,

    #Grupo 90 - Componente solto ou chicote danificado
    "Retrabalho chicote de alta da TCU (Foi grimpado)": 90,
    "Cabo da fonte de alta da TCU solto, foi grimpado": 90,
    "Sem o cabo de alta da TCU": 90,
    "TCU veio sem o cabo de alta": 90,
    "TCU cabo de alta polaridade positivo e negativo invertido": 90,
    "TCU cabo porta fusivel solto e placa inclinometro não apaga o led": 90,
    "Crimpar cabo 11 da TCU": 90,
    "TCU componente solto": 90,
    "Sem a placa do inclinômetro": 90,
    "Conector da bateria solto": 90,
    "Sem bateria do relógio": 90,
    "Troca case superior": 90,
    "TCU sem filtro de alívio": 90,


    #Grupo 91 - Firmware corrompido
    "Atualizar firmware": 91,

    #Grupo 92 - Problema no DCDC (Potência)
    "Falha parãmetros DC/DC teste de potência": 92,

    #Grupo 93 - Falha na Subtensão (Potência)
    "TCU não moveu durante o teste (falha sub tensão bate no teste de potência)": 93,
    "Falha no parâmetro de subtensão da bateria (ERRO PERSISTE)": 93,

    #Grupo 94 - Curto circuito na bateria (Potência)
    "TCU apresenta mensagem de curto circuito na placa (Teste de potência)": 94,
    "Falha no parâmetro de curto-bateria": 94,
    
    #Grupo 95 - Carga da bateria (Potência)
    "TCU apresenta mensagem de curto circuito na placa (Teste de potência)": 95,
    "Falho parâmetro carga da bateria potência": 95,

    #Grupo 96 - NÃO IDENTIFICADO - REMOVER
    "Falha burn-in": 96,

}
problemas_map = {
    10: "LEDs queimados ou invertidos",
    20:"Ponte H defeituosa",
    30: "TCU não ligou na bateria (geral)",
    40: "TCU não comunica",
    41: "Comunicação serial intermitente",
    50: "RAK Defeituosa",
    60: "TCU não ligou na bateria (corrente baixa)",
    61: "TCU não ligou na bateria (corrente alta)",
    70: "Falha na temporarização",
    80: "Problema no ADC (Comunicação)",
    81: "Problema no RTC",
    83: "Problema na EEPROM",
    84: "Problema no Inclinômetro",
    90: "Componente solto ou chicote danificado",
    91: "Firmware corrompido",
    92: "Problema no DCDC (Potência)",
    93: "Falha na Subtensão (Potência)",
    94: "Curto circuito na bateria (Potência)",
    95: "Carga da bateria (Potência)",
    96: "NÃO IDENTIFICADO - REMOVER",
}

df["PROBLEMA_ID"] = df["PROBLEMA"].replace(substituicoes)
df["PROBLEMA"] = df["PROBLEMA_ID"].map(problemas_map).combine_first(df["PROBLEMA"])

print(len(df["PROBLEMA"]))
print(len(df["PROBLEMA"].unique()))
display(df["PROBLEMA"].value_counts())
# Out:
# 264
# 20
# PROBLEMA
# Corrente baixa                                   54
# TCU não ligou na bateria                         51
# TCU não comunica                                 37
# LEDs queimados ou invertidos                     36
# Comunicação serial intermitente                  22
# Ponte H defeituosa                               20
# Componente solto ou chicote danificado           15
# Problema no ADC (Comunicação)                     6
# RAK Defeituosa                                    4
# Problema no RTC                                   3
# Falha na temporarização                           3
# Carga da bateria (Potência)                       2
# Falha na Subtensão (Potência)                     2
# Problema no Inclinômetro                          2
# Problema na EEPROM                                2
# Problema no DCDC (Potência)                       1
# Falha na ponte H (Led do motor não acenderam)     1
# Firmware corrompido                               1
# ...
