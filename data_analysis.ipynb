# %%
# %pip install pandas

# %%
from server import Server
import pandas as pd

# df = pd.read_csv("manutencao.csv")
# print(len(df))


server = Server("http://127.0.0.1:8087/api/v1.0/")
data = server.get_manutencao()
df = pd.json_normalize(data)
display(len(df))
# Out:
#      duracao                    horario   id  operador_id.empresa.id  \
# 0      180.0  2025-02-26T00:00:00+00:00    1                       1
# 1      180.0  2025-02-26T00:00:00+00:00    2                       1
# 2      180.0  2025-02-27T00:00:00+00:00    3                       1
# 3      180.0  2025-02-27T00:00:00+00:00    4                       1
# 4      180.0  2025-02-27T00:00:00+00:00    5                       1
# ..       ...                        ...  ...                     ...
# 212    180.0  2025-03-26T00:00:00+00:00  244                       1
# 213    180.0  2025-03-27T00:00:00+00:00  245                       1
# 214    180.0  2025-03-27T00:00:00+00:00  246                       1
# 215    180.0  2025-03-27T00:00:00+00:00  247                       1
# 216    180.0  2025-03-27T00:00:00+00:00  248                       1
#
#     operador_id.empresa.nome  operador_id.id operador_id.nome  \
# 0                     TECSCI              10       Valciscley
# ...
